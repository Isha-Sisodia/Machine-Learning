# %% [markdown]
# <a href="https://colab.research.google.com/github/Isha-Sisodia/Machine-Learning/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# lets take simple data
# Independent variable
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)

# Dependent variable
y = np.array([2, 4, 6, 8, 10])

# Create and Train the model
model = LinearRegression()
model.fit(X, y)

# Make Prediction
y_pred = model.predict(X)

# the result
plt.scatter(X, y, label="Actual Data")
plt.plot(X, y_pred, label="Regression Line")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()

# Check model values
print("Slope (m):", model.coef_[0])
print("Intercept (c):", model.intercept_)
# Out:
# Slope (m): 2.0
# Intercept (c): 0.0
